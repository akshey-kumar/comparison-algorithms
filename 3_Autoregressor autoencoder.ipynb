# %%
import sys
sys.path.append(r'../')
import mat73
import numpy as np
from tqdm import tqdm
from scipy import signal
from matplotlib import cm
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
import matplotlib.colors as mcolors
from matplotlib.lines import Line2D
import matplotlib.animation as animation

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.losses import Loss
from tensorflow.keras.models import Model
from tensorflow.keras import layers, losses

from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
from sklearn.model_selection import KFold
from sklearn.neighbors import NearestNeighbors
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score, mean_squared_error
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# %reload_ext autoreload
# %autoreload 2
from functions import *
# Out:
# 2023-04-06 13:57:20.581099: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-06 13:57:20.660899: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-04-06 13:57:20.660910: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2023-04-06 13:57:20.680401: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-04-06 13:57:21.133309: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-04-06 13:57:21.133369: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-04-06 13:57:21.133375: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
data = Database()
X = data.neuron_traces.T
B = data.states

# %% [markdown]
# ## Preprocessing the data

# %%
time = 1/data.fps*np.arange(0,X.shape[0])
filtered = bandpass(X.T, f_l=1e-10, f_h=0.05, sampling_freq=data.fps).T

nn = np.arange(80,85)
plt.figure(figsize = [10,3])
plt.plot(time, X[:,nn])
plt.figure(figsize = [10,3])
plt.plot(time, filtered[:,nn])
plt.title('After bandpass filtering')
plt.show()

X = filtered

# %% [markdown]
# ### Preparing the data

# %%
# Preparing the data (Method new)
win = 1
win += 1
gap = 1
X_win = np.zeros((X.shape[0]-win-gap, win, X.shape[1]))

for i, _ in enumerate(X_win):
    X_win[i] = X[i:i+win]

Xwin0, Xwin1 = X_win[:,:-1,:], X_win[:,1:,:]
B_1 = B[1:]
X_paired = np.array([Xwin0, Xwin1])
X_paired = np.transpose(X_paired, axes=(1,0,2,3))

# Train test split 
kf = KFold(n_splits=7)
for i, (train_index, test_index) in enumerate(kf.split(X_win)):
    if i==4: 
        # Train test split based on a fold
        X_train, X_test = X_paired[train_index], X_paired[test_index]
        B_train_1, B_test_1 = B_1[train_index], B_1[test_index]       

X0_tr = X_train[:,0,:,:]
X1_tr = X_train[:,1,:,:]
Xdiff_tr = X1_tr - X0_tr
X0_tst = X_test[:,0,:,:]
X1_tst = X_test[:,1,:,:]
Xdiff_tst = X1_tst - X0_tst

# %% [markdown]
# ## Autoregressor-autoencoder

# %%
class Autoencoder(Model):
  def __init__(self, latent_dim):
    super(Autoencoder, self).__init__()
    self.latent_dim = latent_dim   
    self.encoder = tf.keras.Sequential([
        layers.Flatten(),
        layers.Dense(50, activation='relu'),
        layers.Dense(30, activation='relu'),
        layers.Dense(25, activation='relu'),
        layers.Dense(10, activation='relu'),
        layers.Dense(latent_dim, activation='linear'),
    ])
    self.decoder = tf.keras.Sequential([
        layers.Dense(latent_dim, activation='relu'),
        layers.Dense(10, activation='relu'),
        layers.Dense(25, activation='relu'),
        layers.Dense(30, activation='relu'),
        layers.Dense(50, activation='relu'),
        layers.Dense(X1_tr.shape[-1]*X1_tr.shape[-2], activation='linear'),
        layers.Reshape(X1_tr.shape[1:])
    ])
  def call(self, x):
    encoded = self.encoder(x)
    decoded = self.decoder(encoded)
    return decoded

autoencoder = Autoencoder(latent_dim = 3)

opt = tf.keras.optimizers.Adam(learning_rate=0.001)

autoencoder.compile(optimizer=opt,
              loss='mse',
              metrics=['mse'])

# %%
### Scaling input and output data
Xdmax = (np.abs(Xdiff_tr)).max() # Parameters for scaling
Xdiff_tr, Xdiff_tst = Xdiff_tr/Xdmax, Xdiff_tst/Xdmax

# %matplotlib inline
history = autoencoder.fit(X0_tr,
                      Xdiff_tr,
                      epochs=50,
                      batch_size=100,
                      validation_data=(X0_tst, Xdiff_tst),
                      verbose=0,
                      )
# Summarize history for accuracy
plt.plot(history.history['mse'])
plt.plot(history.history['val_mse'])

### Predictions
Xdiff_tr_pred = autoencoder(X0_tr).numpy()
Xdiff_tst_pred = autoencoder(X0_tst).numpy()

# Inverse scaling the data
Xdiff_tr_pred, Xdiff_tr = Xdiff_tr_pred*Xdmax, Xdiff_tr*Xdmax
Xdiff_tst_pred, Xdiff_tst = Xdiff_tst_pred*Xdmax, Xdiff_tst*Xdmax

X1_tr_pred = X0_tr + Xdiff_tr_pred
X1_tst_pred = X0_tst + Xdiff_tst_pred

baseline_tr  = mean_squared_error(flat_partial(X1_tr), flat_partial(X0_tr))
modelmse_tr = mean_squared_error(flat_partial(X1_tr), flat_partial(X1_tr_pred))
baseline_tst  = mean_squared_error(flat_partial(X1_tst), flat_partial(X0_tst))
modelmse_tst = mean_squared_error(flat_partial(X1_tst), flat_partial(X1_tst_pred))

print('On training set \n')
print('Baseline mse', baseline_tr.round(8), 'Model mse:', modelmse_tr.round(8))
print('\nOn test set \n')
print('Baseline mse', baseline_tst.round(8), 'Model mse:', modelmse_tst.round(8))
# Out:
# On training set
#
# Baseline mse 4.633e-05 Model mse: 8.19e-06
#
# On test set
#
# Baseline mse 2.382e-05 Model mse: 1.261e-05

# %% [markdown]
# #### Projecting into latent space

# %%
Y0_tr = autoencoder.encoder(X0_tr).numpy()
Y1_tr = autoencoder.encoder(X1_tr).numpy()
Ydiff_tr = Y1_tr - Y0_tr

Y0_tst = autoencoder.encoder(X0_tst).numpy()
Y1_tst = autoencoder.encoder(X1_tst).numpy()
Ydiff_tst = Y1_tst - Y0_tst

np.savetxt('Saved_Y/Y0_tr__autoregressor.csv',Y0_tr)
np.savetxt('Saved_Y/Y1_tr__autoregressor.csv',Y1_tr)
np.savetxt('Saved_Y/Y0_tst__autoregressor.csv',Y0_tst)
np.savetxt('Saved_Y/Y1_tst__autoregressor.csv',Y1_tst)
np.savetxt('Saved_Y/B_train_1__autoregressor.csv',B_train_1)
np.savetxt('Saved_Y/B_test_1__autoregressor.csv',B_test_1)

# %% [markdown]
# ### Plotting latent space dynamics

# %%
### Dynamics in the (learned) latent space
# %matplotlib inline
plt.figure(figsize=(19,5))
plt.imshow([B_train_1],aspect=600,cmap="Pastel1")
cbar = plt.colorbar(ticks=np.arange(8))
cbar.ax.set_yticklabels(['Dorsal turn', 'Forward', 'No state', 'Reverse-1', 'Reverse-2', 'Sustained reverse', 'Slowing', 'Ventral turn']) 
plt.plot(Y0_tr/Y0_tr.max()/3)
plt.xlabel("time $t$")
plt.axis([0,Y0_tr.shape[0],-0.5,0.5])
# Out:
# (0.0, 2686.0, -0.5, 0.5)

# %%
# %matplotlib notebook
plot_phase_space(Y0_tr, B_train_1)
# Out:
# <img src="data:image/png;base64,..." width="800">
# <Axes3DSubplot: >

# %%
### Run to produce rotating 3-D plot
# %matplotlib notebook    
rotating_plot(Y0_tr, B_train_1)
# Out:
# <img src="data:image/png;base64,..." width="576.25">
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/.local/lib/python3.8/site-packages/matplotlib/animation.py:234, in AbstractMovieWriter.saving(self, fig, outfile, dpi, *args, **kwargs)
#     233 try:
# --> 234     yield self
#     235 finally:
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/animation.py:1093, in Animation.save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1092         frame_number += 1
# -> 1093 writer.grab_frame(**savefig_kwargs)
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/animation.py:351, in MovieWriter.grab_frame(self, **savefig_kwargs)
#     350 # Save the figure data to the sink, using the frame format and dpi.
# --> 351 self.fig.savefig(self._proc.stdin, format=self.frame_format,
#     352                  dpi=self.dpi, **savefig_kwargs)
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/figure.py:3046, in Figure.savefig(self, fname, transparent, **kwargs)
#    3043         stack.enter_context(
#    3044             ax.patch._cm_set(facecolor='none', edgecolor='none'))
# -> 3046 self.canvas.print_figure(fname, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/backend_bases.py:2319, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2318     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2319         result = print_method(
#    2320             filename,
#    2321             facecolor=facecolor,
#    2322             edgecolor=edgecolor,
#    2323             orientation=orientation,
#    2324             bbox_inches_restore=_bbox_inches_restore,
#    2325             **kwargs)
#    2326 finally:
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/backend_bases.py:1648, in _check_savefig_extra_args.<locals>.wrapper(*args, **kwargs)
#    1646     kwargs.pop(arg)
# -> 1648 return func(*args, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/_api/deprecation.py:415, in delete_parameter.<locals>.wrapper(*inner_args, **inner_kwargs)
#     408     warn_deprecated(
#     409         since,
#     410         name=repr(name),
#    (...)
#     413                  else deprecation_addendum,
#     414         **kwargs)
# --> 415 return func(*inner_args, **inner_kwargs)
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:483, in FigureCanvasAgg.print_raw(self, filename_or_obj, *args)
#     480 @_check_savefig_extra_args
#     481 @_api.delete_parameter("3.5", "args")
#     482 def print_raw(self, filename_or_obj, *args):
# --> 483     FigureCanvasAgg.draw(self)
#     484     renderer = self.get_renderer()
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:436, in FigureCanvasAgg.draw(self)
#     433 with RendererAgg.lock, \
#     434      (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     435       else nullcontext()):
# --> 436     self.figure.draw(self.renderer)
#     437     # A GUI class may be need to update a window using this draw, so
#     438     # don't forget to call the superclass.
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/artist.py:73, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      71 @wraps(draw)
#      72 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 73     result = draw(artist, renderer, *args, **kwargs)
#      74     if renderer._rasterizing:
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/artist.py:50, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      48         renderer.start_filter()
# ---> 50     return draw(artist, renderer)
#      51 finally:
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/figure.py:2837, in Figure.draw(self, renderer)
#    2836 self.patch.draw(renderer)
# -> 2837 mimage._draw_list_compositing_images(
#    2838     renderer, self, artists, self.suppressComposite)
#    2840 for sfig in self.subfigs:
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/artist.py:50, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      48         renderer.start_filter()
# ---> 50     return draw(artist, renderer)
#      51 finally:
#
# File ~/.local/lib/python3.8/site-packages/mpl_toolkits/mplot3d/axes3d.py:473, in Axes3D.draw(self, renderer)
#     472 # Then rest
# --> 473 super().draw(renderer)
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/artist.py:50, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      48         renderer.start_filter()
# ---> 50     return draw(artist, renderer)
#      51 finally:
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/axes/_base.py:3091, in _AxesBase.draw(self, renderer)
#    3089     renderer.stop_rasterizing()
# -> 3091 mimage._draw_list_compositing_images(
#    3092     renderer, self, artists, self.figure.suppressComposite)
#    3094 renderer.close_group('axes')
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/artist.py:50, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      48         renderer.start_filter()
# ---> 50     return draw(artist, renderer)
#      51 finally:
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/legend.py:628, in Legend.draw(self, renderer)
#     627 self.legendPatch.draw(renderer)
# --> 628 self._legend_box.draw(renderer)
#     630 renderer.close_group('legend')
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/offsetbox.py:362, in OffsetBox.draw(self, renderer)
#     359 width, height, xdescent, ydescent, offsets = self.get_extent_offsets(
#     360                                                 renderer)
# --> 362 px, py = self.get_offset(width, height, xdescent, ydescent, renderer)
#     364 for c, (ox, oy) in zip(self.get_visible_children(), offsets):
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/offsetbox.py:290, in OffsetBox.get_offset(self, width, height, xdescent, ydescent, renderer)
#     276 """
#     277 Return the offset as a tuple (x, y).
#     278
#    (...)
#     288
#     289 """
# --> 290 return (self._offset(width, height, xdescent, ydescent, renderer)
#     291         if callable(self._offset)
#     292         else self._offset)
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/legend.py:589, in Legend._findoffset(self, width, height, xdescent, ydescent, renderer)
#     588 if self._loc == 0:  # "best".
# --> 589     x, y = self._find_best_position(width, height, renderer)
#     590 elif self._loc in Legend.codes.values():  # Fixed location.
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/legend.py:1030, in Legend._find_best_position(self, width, height, renderer, consider)
#    1028 # XXX TODO: If markers are present, it would be good to take them
#    1029 # into account when checking vertex overlaps in the next line.
# -> 1030 badness = (sum(legendBox.count_contains(line.vertices)
#    1031                for line in lines)
#    1032            + legendBox.count_contains(offsets)
#    1033            + legendBox.count_overlaps(bboxes)
#    1034            + sum(line.intersects_bbox(legendBox, filled=False)
#    1035                  for line in lines))
#    1036 if badness == 0:
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/legend.py:1030, in <genexpr>(.0)
#    1028 # XXX TODO: If markers are present, it would be good to take them
#    1029 # into account when checking vertex overlaps in the next line.
# -> 1030 badness = (sum(legendBox.count_contains(line.vertices)
#    1031                for line in lines)
#    1032            + legendBox.count_contains(offsets)
#    1033            + legendBox.count_overlaps(bboxes)
#    1034            + sum(line.intersects_bbox(legendBox, filled=False)
#    1035                  for line in lines))
#    1036 if badness == 0:
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/transforms.py:606, in BboxBase.count_contains(self, vertices)
#     605 with np.errstate(invalid='ignore'):
# --> 606     return (((self.min < vertices) &
#     607              (vertices < self.max)).all(axis=1).sum())
#
# File ~/.local/lib/python3.8/site-packages/numpy/core/_ufunc_config.py:435, in errstate.__exit__(self, *exc_info)
#     434 def __exit__(self, *exc_info):
# --> 435     seterr(**self.oldstate)
#     436     if self.call is not _Unspecified:
#
# File ~/.local/lib/python3.8/site-packages/numpy/core/_ufunc_config.py:110, in seterr(all, divide, over, under, invalid)
#     109 pyvals = umath.geterrobj()
# --> 110 old = geterr()
#     112 if divide is None:
#
# File ~/.local/lib/python3.8/site-packages/numpy/core/_ufunc_config.py:170, in geterr()
#     169 res = {}
# --> 170 val = (maskvalue >> SHIFT_DIVIDEBYZERO) & mask
#     171 res['divide'] = _errdict_rev[val]
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# CalledProcessError                        Traceback (most recent call last)
# Input In [42], in <cell line: 3>()
#       1 ### Run to produce rotating 3-D plot
#       2 get_ipython().run_line_magic('matplotlib', 'notebook')
# ----> 3 rotating_plot(Y0_tr, B_train_1)
#
# File ~/Desktop/PhD/Code_repositories/dcc-autoencoder/Results for paper/functions.py:129, in rotating_plot(Y, B)
#     127 ax.legend(handles=legend_elements)
#     128 rot_animation = animation.FuncAnimation(fig, rotate, frames=np.arange(0, 362, 5), interval=150)
# --> 129 rot_animation.save('rotation.gif', dpi=80, writer='imagemagick')
#     130 plt.show()
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/animation.py:1093, in Animation.save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1091         progress_callback(frame_number, total_frames)
#    1092         frame_number += 1
# -> 1093 writer.grab_frame(**savefig_kwargs)
#
# File /usr/lib/python3.8/contextlib.py:131, in _GeneratorContextManager.__exit__(self, type, value, traceback)
#     129     value = type()
#     130 try:
# --> 131     self.gen.throw(type, value, traceback)
#     132 except StopIteration as exc:
#     133     # Suppress StopIteration *unless* it's the same exception that
#     134     # was passed to throw().  This prevents a StopIteration
#     135     # raised inside the "with" statement from being suppressed.
#     136     return exc is not value
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/animation.py:236, in AbstractMovieWriter.saving(self, fig, outfile, dpi, *args, **kwargs)
#     234     yield self
#     235 finally:
# --> 236     self.finish()
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/animation.py:342, in MovieWriter.finish(self)
#     340     overridden_cleanup()
#     341 else:
# --> 342     self._cleanup()
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/animation.py:373, in MovieWriter._cleanup(self)
#     369     _log.log(
#     370         logging.WARNING if self._proc.returncode else logging.DEBUG,
#     371         "MovieWriter stderr:\n%s", err)
#     372 if self._proc.returncode:
# --> 373     raise subprocess.CalledProcessError(
#     374         self._proc.returncode, self._proc.args, out, err)
#
# CalledProcessError: Command '['convert', '-size', '640x640', '-depth', '8', '-delay', '15.0', '-loop', '0', 'rgba:-', 'rotation.gif']' returned non-zero exit status 2.

# %% [markdown]
# ### Performing PCA on the latent dimension

# %%
# %matplotlib inline
pca = PCA()
Y_pca = pca.fit_transform(Y0_tr)
plt.figure(figsize=(19,5))
plt.imshow([B_train_1],aspect=600,cmap="Pastel1")
cbar = plt.colorbar(ticks=np.arange(8))
cbar.ax.set_yticklabels(['Dorsal turn', 'Forward', 'No state', 'Reverse-1', 'Reverse-2', 'Sustained reverse', 'Slowing', 'Ventral turn']) 
plt.plot(Y_pca/Y_pca.max()/3)
plt.xlabel("time $t$")
plt.ylabel("$Y_{pca}$")
plt.axis([0,Y_pca.shape[0],-0.5,0.5])
# Out:
# (0.0, 2686.0, -0.5, 0.5)

# %% [markdown]
# ### Behaviour predictor

# %%
# %matplotlib inline
b_predictor = tf.keras.Sequential([
#    layers.Dense(80, activation='relu'),
    layers.Dense(20, activation='relu'),
    layers.Dense(8, activation='linear')
]) 
opt = tf.keras.optimizers.Adam(learning_rate=0.01)

b_predictor.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

history = b_predictor.fit(Y1_tr,
                      B_train_1,
                      epochs=100,
                      batch_size=100,
                      validation_data=(Y1_tst, B_test_1),
                      verbose=0
                      )

# Summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])

# %%
B1_pred = b_predictor(Y1_tst).numpy().argmax(axis=1)
accuracy_score(B1_pred, B_test_1)
# Out:
# 0.734375

# %%
plt.plot(B1_pred)
plt.plot(B_test_1)

# %% [markdown]
# ### Autoregressor: Predicting $Y_{t+1}$ from $Y_t$

# %%
# Defining the model
model_ydiff_f_yt = tf.keras.Sequential([
    #tf.keras.layers.Dense(3, activation='relu'),
    #tf.keras.layers.Dense(5, activation='relu'),
    #tf.keras.layers.Dense(7, activation='relu'),
    #tf.keras.layers.Dense(10, activation='relu'),
    #tf.keras.layers.Dense(7, activation='relu'),
    #tf.keras.layers.Dense(5, activation='relu'),
    tf.keras.layers.Dense(3, activation='linear')
])

opt = tf.keras.optimizers.Adam(learning_rate=0.01)

model_ydiff_f_yt.compile(optimizer=opt,
              loss='mse',
              metrics=['mse'])


history = model_ydiff_f_yt.fit(Y0_tr,
                      Ydiff_tr,
                      epochs=25,
                      batch_size=100,
                      validation_data=(Y0_tst, Ydiff_tst),
                      verbose=0
                      )

# Summarize history for accuracy
plt.plot(history.history['mse'])
plt.plot(history.history['val_mse'])

Ydiff_tr_pred = model_ydiff_f_yt(Y0_tr).numpy()
Y1_tr_pred = Y0_tr + Ydiff_tr_pred

Ydiff_tst_pred = model_ydiff_f_yt(Y0_tst).numpy()
Y1_tst_pred = Y0_tst + Ydiff_tst_pred

baseline_tr  = mean_squared_error(flat_partial(Y1_tr), flat_partial(Y0_tr))
modelmse_tr = mean_squared_error(flat_partial(Y1_tr), flat_partial(Y1_tr_pred))
baseline_tst  = mean_squared_error(flat_partial(Y1_tst), flat_partial(Y0_tst))
modelmse_tst = mean_squared_error(flat_partial(Y1_tst), flat_partial(Y1_tst_pred))

print('On training set \n')
print('Baseline mse', baseline_tr.round(8), 'Model mse:', modelmse_tr.round(8))
print('\nOn test set \n')
print('Baseline mse', baseline_tst.round(8), 'Model mse:', modelmse_tst.round(8))
# Out:
# On training set
#
# Baseline mse 0.00016543 Model mse: 8.773e-05
#
# On test set
#
# Baseline mse 7.886e-05 Model mse: 5.211e-05

# %% [markdown]
# #### Autoregression: with linear regression
# (deterministic as opposed to probabilistic neural net's solution)

# %%
linear_reg = LinearRegression()
linear_reg.fit(Y0_tr, Ydiff_tr)
Ydiff_tst_pred = linear_reg.predict(Y0_tst)

Y1_tst_pred = Y0_tst + Ydiff_tst_pred

baseline_tst  = mean_squared_error(flat_partial(Y1_tst), flat_partial(Y0_tst))
modelmse_tst = mean_squared_error(flat_partial(Y1_tst), flat_partial(Y1_tst_pred))
print('\nOn test set \n')
print('Baseline mse', baseline_tst.round(8), 'Model mse:', modelmse_tst.round(8))
1 - modelmse_tst/baseline_tst
# Out:
# On test set
#
# Baseline mse 7.886e-05 Model mse: 5.013e-05
# 0.36433809995651245

# %%
hits_at_rank(5,Y1_tr, Y1_tr_pred)
# Out:
# 0.6667907669396873
